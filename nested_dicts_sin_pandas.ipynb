u'78856': 0, u'72893': 0, u'305154': 0, u'72816': 0, u'74222': 0, u'78373': 0, u'78217': 0, u'333597': 0, u'76633': 0, u'69913': 0, u'78896': 0, u'83481': 0, u'74480': 0, u'83163': 0, u'68468': 0, u'67207': 0, u'68928': 100.0, u'69181': 0, u'79786': 0, u'71909': 0, u'72260': 0, u'69067': 0, u'76307': 0, u'69133': 0, u'80585': 0, u'72195': 0, u'78449': 0, u'79772': 0, u'70996': 0, u'83707': 100.0, u'80637': 0, u'84044': 0, u'81992': 0, u'80402': 0}, {u'76393': 0, u'80093': 0, u'72584': 0, u'66709': 0, u'69375': 0, u'83955': 0, u'78856': 0, u'72893': 0, u'305154': 0, u'72816': 0, u'74222': 0, u'78373': 0, u'78217': 0, u'333597': 0, u'76633': 0, u'69913': 0, u'78896': 0, u'83481': 0, u'74480': 0, u'83163': 0, u'68468': 0, u'67207': 0, u'68928': 100.0, u'69181': 0, u'79786': 0, u'71909': 0, u'72260':
0, u'69067': 0, u'76307': 0, u'69133': 0, u'80585': 0, u'72195': 0, u'78449': 0, u'79772': 0, u'70996': 0, u'83707': 100.0, u'80637': 0, u'84044': 0, u'81992': 0, u'80402': 100.0}, None], u'Error': u'TypeError'}}}

# %%
el_dict
# Out:
# {u'81884': {u'KPI_1': {u'Data': [None, None, None],
#    u'MissingPegs': [],
#    u'MissingPegsDetail': [[], [], []]},
#   u'KPI_2': {u'Data': [{u'305154': 0.0,
#      u'333597': 0.0,
#      u'66709': 0.0,
#      u'67207': 0.0,
#      u'68468': 0.0,
#      u'68928': 24.0,
#      u'69067': 0.0,
#      u'69133': 0.0,
#      u'69181': 0.0,
#      u'69375': 0.0,
#      u'69913': 0.0,
#      u'70996': 0.0,
#      u'71909': 0.0,
#      u'72195': 0.0,
#      u'72260': 0.0,
#      u'72584': 0.0,
#      u'72816': 0.0,
#      u'72893': 0.0,
#      u'74222': 0.0,
#      u'74480': 0.0,
#      u'76307': 0.0,
#      u'76393': 0.0,
#      u'76633': 0.0,
#      u'78217': 0.0,
#      u'78373': 0.0,
#      u'78449': 0.0,
#      u'78856': 0.0,
#      u'78896': 0.0,
#      u'79772': 0.0,
#      u'79786': 0.0,
#      u'80093': 0.0,
#      u'80402': 0.0,
#      u'80585': 0.0,
#      u'80637': 0.0,
#      u'81992': 0.0,
#      u'83163': 0.0,
#      u'83481': 0.0,
#      u'83707': 19.0,
# ...

# %%
for key, value in parameter_dict.iteritems():
            # error handling: for some reason it returned no value...
            if value:
                #key is the cell, each value is the NeighborRelations
                for key2, value2 in value.iteritems():
                    if value2:
                        #key2 is neighborlists, value is a list of neighbors
                        for key3, value3 in value2.iteritems():
                            if value3:
                                #key3 is the type of neighbors, #value3 is the list of neighbors of that type
                                if key3 == 'InterRAT':
                                    #value3 is a list of dictionaries
                                    for neighbor in value3:
                                        #dn is the dn of the neighbor, the values are all the neighbor parameters
                                        #we are going to populate a new dictionary with:
                                        #key: neighbor_dn
                                        #neighbor info (nested dictionary): origin cell, adjacent cell, RNCID, cid, name, coverageindicator
                                        if neighbor['adjacentCell']:
                                            #error handling: for some reason there are neighbors with adjacentCell = None
                                            neighbor_dict[neighbor['dn']]={
                                                'origin_cell': key[key.find('EUtranCellFDD=')+14:],
                                                'destination_cell': neighbor['adjacentCell'][neighbor['adjacentCell'].find('ExternalUtranCell=')+23:],
                                                'coverageIndicator': neighbor['coverageIndicator']}
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-3-1ee70a67d602> in <module>()
# ----> 1 for key, value in parameter_dict.iteritems():
#       2             # error handling: for some reason it returned no value...
#       3             if value:
#       4                 #key is the cell, each value is the NeighborRelations
#       5                 for key2, value2 in value.iteritems():
#
# NameError: name 'parameter_dict' is not defined

# %%
def mean(numbers):
    return float(sum(numbers)) / max(len(numbers), 1)

# %%
# Creamos los diccionarios que vamos a rellenar
uid_kpi_dict = {}
kpi_value_dict = {}
kpi_val_dict = {}
kpi_val_dict_avg = {}

# %%
for key, value in el_dict.iteritems():
    # print(key) --> celda --> 81884
    # print(value) --> Diccionario con los KPIS y sus valores --> {u'GSM_IRAT_incFromUMTS_HO_Success': {u'MissingPegs': [], u'MissingPegsDetail': [[], [], []], u'Data': [None, None, None]}, u'HO_Success_Gcell': {u'MissingPegs': [u'necellrel.hoversuc', u'ncellrel.hoversuc'], u'MissingPegsDetail': [[u'necellrel.hoversuc'], [u'necellrel.hoversuc'], [u'necellrel.hoversuc', u'ncellrel.hoversuc']], u'Data': [{u'79786': 0.0, u'71909': 0.0, u'76393': 0.0, u'69133': 0.0, u'80093': 0.0, u'79772': 0.0, u'84044': 0.0, u'72584': 0.0, u'72260': 0.0, u'69067': 0.0, u'66709': 0.0, u'76307': 0.0, u'69375': 0.0, u'83955': 0.0, u'78856': 0.0, u'72893': 0.0, u'80585': 0.0, u'305154': 0.0, u'72195': 0.0, u'72816': 0.0, u'80402': 0.0, u'74222': 0.0, u'70996': 0.0, u'78373': 0.0, u'78217': 0.0, u'333597': 0.0, u'78449': 0.0, u'76633': 0.0, u'69913': 0.0, u'78896': 0.0, u'83481': 0.0, u'74480': 0.0, u'83163': 0.0, u'68468': 0.0, u'67207': 0.0, u'68928': 24.0, u'83707': 19.0, u'81992': 0.0, u'80637': 0.0, u'69181': 0.0}, {u'79786': 0.0, u'71909': 0.0, u'76393': 0.0, u'69133': 0.0, u'80093': 0.0, u'79772': 0.0, u'84044': 0.0, u'72584': 0.0, u'72260': 0.0, u'69067': 0.0, u'66709': 0.0, u'76307': 0.0, u'69375': 0.0, u'83955': 0.0, u'78856': 0.0, u'72893': 0.0, u'80585': 0.0, u'305154': 0.0, u'72195': 0.0, u'72816': 0.0, u'80402': 1.0, u'74222': 0.0, u'70996': 0.0, u'78373': 0.0, u'78217': 0.0, u'333597': 0.0, u'78449': 0.0, u'76633': 0.0, u'69913': 0.0, u'78896': 0.0, u'83481': 0.0, u'74480': 0.0, u'83163': 0.0, u'68468': 0.0, u'67207': 0.0, u'68928': 35.0, u'83707': 21.0, u'81992': 0.0, u'80637': 0.0, u'69181': 0.0}, None]}, u'IRATHO_WCDMA_Attempts': {u'MissingPegs': [u'nucellrel.hovercntutran'],
    uid_kpi_dict[key] = value
    
    for key2, value2 in value.iteritems():
        # print(key2) --> KPI --> GSM_IRAT_incFromUMTS_HO_Success
        # print(value2) --> Valores de ese KPI (en dic anidados) --> {u'MissingPegs': [u'necellrel.hoversuc', u'ncellrel.hoversuc'], u'MissingPegsDetail': [[u'necellrel.hoversuc'], [u'necellrel.hoversuc'], [u'necellrel.hoversuc', u'ncellrel.hoversuc']], u'Data': [{u'79786': 0.0, u'71909': 0.0, u'76393': 0.0, u'69133': 0.0, u'80093': 0.0, u'79772': 0.0, u'84044': 0.0, u'72584': 0.0, u'72260': 0.0, u'69067': 0.0, u'66709': 0.0, u'76307': 0.0, u'69375': 0.0, u'83955': 0.0, u'78856': 0.0, u'72893': 0.0, u'80585': 0.0, u'305154': 0.0, u'72195': 0.0, u'72816': 0.0, u'80402': 0.0, u'74222': 0.0, u'70996': 0.0, u'78373': 0.0, u'78217': 0.0, u'333597': 0.0, u'78449': 0.0, u'76633': 0.0, u'69913': 0.0, u'78896': 0.0, u'83481': 0.0, u'74480': 0.0, u'83163': 0.0, u'68468': 0.0, u'67207': 0.0, u'68928': 24.0, u'83707': 19.0, u'81992': 0.0, u'80637': 0.0, u'69181': 0.0}, {u'79786': 0.0, u'71909': 0.0, u'76393': 0.0, u'69133': 0.0, u'80093': 0.0, u'79772': 0.0, u'84044': 0.0, u'72584': 0.0, u'72260': 0.0, u'69067': 0.0, u'66709': 0.0, u'76307': 0.0, u'69375': 0.0, u'83955': 0.0, u'78856': 0.0, u'72893': 0.0, u'80585': 0.0, u'305154': 0.0, u'72195': 0.0, u'72816': 0.0, u'80402': 1.0, u'74222': 0.0, u'70996': 0.0, u'78373': 0.0, u'78217': 0.0, u'333597': 0.0, u'78449': 0.0, u'76633': 0.0, u'69913': 0.0, u'78896': 0.0, u'83481': 0.0, u'74480': 0.0, u'83163': 0.0, u'68468': 0.0, u'67207': 0.0, u'68928': 35.0, u'83707': 21.0, u'81992': 0.0, u'80637': 0.0, u'69181': 0.0}, None]}
        
        kpi_value_dict[key2] = value2
        
        # Tenemos que crear un dict que va a ser: {KPI_name : suma_valores}
        dic_res = {}

        for key3, value3 in value2.iteritems():
             #print(key3) #--> Una mierda rara de los datos --> MissingPegsDetail
             #print(value3) #--> listas con los valores de los KPI o None --> [{u'79786': 0.0, u'71909': 0.0, u'76393': 0.0, u'69133': 0.0, u'80093': 0.0, u'79772': 0.0, u'84044': 0.0, u'72584': 0.0, u'72260': 0.0, u'69067': 0.0, u'66709': 0.0, u'76307': 0.0, u'69375': 0.0, u'83955': 0.0, u'78856': 0.0, u'72893': 0.0, u'80585': 0.0, u'305154': 0.0, u'72195': 0.0, u'72816': 0.0, u'80402': 0.0, u'74222': 0.0, u'70996': 0.0, u'78373': 0.0, u'78217': 0.0, u'333597': 0.0, u'78449': 0.0, u'76633': 0.0, u'69913': 0.0, u'78896': 0.0, u'83481': 0.0, u'74480': 0.0, u'83163': 0.0, u'68468': 0.0, u'67207': 0.0, u'68928': 24.0, u'83707': 19.0, u'81992': 0.0, u'80637': 0.0, u'69181': 0.0}, {u'79786': 0.0, u'71909': 0.0, u'76393': 0.0, u'69133': 0.0, u'80093': 0.0, u'79772': 0.0, u'84044': 0.0, u'72584': 0.0, u'72260': 0.0, u'69067': 0.0, u'66709': 0.0, u'76307': 0.0, u'69375': 0.0, u'83955': 0.0, u'78856': 0.0, u'72893': 0.0, u'80585': 0.0, u'305154': 0.0, u'72195': 0.0, u'72816': 0.0, u'80402': 1.0, u'74222': 0.0, u'70996': 0.0, u'78373': 0.0, u'78217': 0.0, u'333597': 0.0, u'78449': 0.0, u'76633': 0.0, u'69913': 0.0, u'78896': 0.0, u'83481': 0.0, u'74480': 0.0, u'83163': 0.0, u'68468': 0.0, u'67207': 0.0, u'68928': 35.0, u'83707': 21.0, u'81992': 0.0, u'80637': 0.0, u'69181': 0.0}, None]
            # Comprobamos si key3 es Data, si no, no nos interesa
            if(key3 == 'Data'): 
                for v in value3:      
                    # Tenemos que filtrar los valores que no sean None
                    #print(v) #--> los valores de las listas que son 'Data'
                    #if(type(v) is not None or v is not 'None'):
                    if(type(v) is dict):
                        for ki, val in v.iteritems():
                            suma = sum(v.values())
                            avg = mean(v.values())
                            #dic_res = [x for x in dic_res[v.values]]
                            #print(val)
                            #dic_res[key2] = suma
                            #dic_res[key2] = dic_res.get(key2, ()) + v.values())
                            #gsm_result_E.update(kpi_client.getKPI([x], gsm_kpi_name, interval_hr, 3))
                            #data[aKey].update(dataResults)
                            #dic_res[key].append(suma)
                            #mytuple=(key2,suma)
                            #dic_res.update(mytuple)
                            
                            kpi_val_dict[key2] = suma
                            kpi_val_dict_avg[key2] = avg
                            
#print(suma)
#print(avg)
#print(dic_res)
#print(len(ki))

#print(uid_kpi_dict)
#print(kpi_value_dict)
#print(kpi_val_dict)
            
kpi_matrix =[]

kpi_matrix = [uid_kpi_dict.keys(), kpi_val_dict.keys(), kpi_val_dict.values(), kpi_val_dict_avg.values()]

kpi_matrix
# Out:
# [[u'81884'],
#  [u'KPI_6', u'KPI_7', u'KPI_4', u'KPI_2', u'KPI_3'],
#  [1.0, 300.0, 57.0, 57.0, 1.0],
#  [0.029411764705882353, 7.5, 1.425, 1.425, 0.029411764705882353]]

# %% [markdown]
# # jkjk###########################

# %%
# Accedemos a la posicion
h = kpi_matrix[0][0], kpi_matrix[1][0], kpi_matrix[2][0], kpi_matrix[3][0]
h
# Out:
# (u'81884', u'KPI_6', 1.0, 0.029411764705882353)

# %%
# Distinguimos cuando hay que hacer la suma o cuando el promedio
matching_1 = [s for s in kpi_matrix if "rate" in s]
matching_2 = [s for s in kpi_matrix if "ratio" in s]
matching_3 = [s for s in kpi_matrix if "%" in s]

# %%
# Accedemos a cada elemento de la lista
#for i in len(kpi_matrix):
for i in xrange(1,len(kpi_matrix)):
    # print i
    
    #Ahora necesitamos acceder a cada lista de la lista grande
    #for j in i:
    for j in xrange(1,(i)):
        print j
        
        # Ponemos la UID
        print(kpi_matrix[i][0])
        
        # Ponemos los KPIs
        print(kpi_matrix[i][j])
        
        # Ponemos los values de los KPIs
        # Caso de que hagamos el promedio
        if (matching_1 or matching_2 or matching_3):
            kpi_matrix[3][0]
        # Caso de que hagamos la suma
        kpi_matrix[2][0]
# Out:
# 1
# 1.0
# 300.0
# 1
# 0.0294117647059
# 7.5
# 2
# 0.0294117647059
# 1.425

# %% [markdown]
# ## Excel Output

# %%
def Excel_Output(mtx_kpi_cell, output_file_name):
    
    print 'writing file:', output_file_name

    # work BOOK
    wb = xlsxwriter.Workbook(output_file_name, {'constant_memory': True})
    ws = wb.add_worksheet('GSM_E')
#    ws.write_row('A1', ('UID','HO_Success_Gcell','HO_Attempts_Gcell','IRATHO_WCDMA_Attempts','IRATHO_WCDMA_Successes',
#                       'HO_Success_Ratio_Gcell'))
    
     ws.write_row('A1', ('UID','KPI_list'))
    
    out_file_index = 1
    # nested dictionaries required to push changes to OSS
    # dic_kpi_cell is a dictionary where
        # key: uid
        # value: dictionary with all the changes required:
            # key2: cell
            # value2: dictionary with the new parameter:
                # key3: parameter name
                # parameter3: parameter value
    for dt in mtx_kpi_cell:
        for key, value in dt.iteritems():            
            if key =='UID' :
                print value
                #ws.write_row(out_file_index,0, value)
            if key=='kpi_name':
                for value2 in value:
                    print value2
                    if value2 =='HO_Success_Ratio_Gcell'
                        #mtx_kpi_cell[0]['kpi_value_avg:']
                        ws._write_row(1,1,mtx_kpi_cell[0]['kpi_value_avg:'])
                    #ws.write_row(out_file_index,0, value2)

            if key =='kpi_value_suma' :
                print value
                #ws.write_row(out_file_index,0, value)
            if key =='kpi_value_avg' :
                print value
                #ws.write_row(out_file_index,0, value)
                
                #ws.write_row(out_file_index, 0, (key2[key2.find('OSP E/ 2G % 2G to 3G IRAT HO Success (excluding preparation)=') + 14:key2.find('EUtranCellFDD=') + 25],
                #                             key2, value2.keys()[0], value2.values()[0]))            
            out_file_index += 1

    # finish writing
    wb.close()

    return None
